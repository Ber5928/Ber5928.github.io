# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
for year in range (2018 ,2023) # want year >= 2018
    url = "https://www.pro-football-reference.com/years/{}/fantasy.htm".format(year) #string formatting to manipulate the url by a given year
    html = urlopen(url)
    soup = BeautifulSoup(html)
# Out:
#   Cell In[12], line 1
#     for year in range (2018 ,2023) # want year >= 2018
#                                    ^
# SyntaxError: expected ':'

# %%
headers = [th.getText() for th in soup.findAll('tr')[1].findAll('th')] #Find the second table row tag, find every table header column within it and extract the html text via the get_text method.
headers = headers[1:] #Do not need the first (0 index) column header
print(headers[:5])
# Out:
# ['Player', 'Tm', 'FantPos', 'Age', 'G']

# %%
rows = soup.findAll('tr', class_ = lambda table_rows: table_rows != "thead") #Here we grab all rows that are not classed as table header rows - football reference throws in a table header row everyy 30 rows 
player_stats = [[td.getText() for td in rows[i].findAll('td')] # get the table data cell text from each table data cell
                for i in range(len(rows))] #for each row
player_stats = player_stats[2:]

# %%
stats = pd.DataFrame(player_stats, columns = headers)
stats
# Out:
#                Player   Tm FantPos Age   G  GS  Cmp  Att   Yds  TD  ...  TD  \
# 0       Todd Gurley*+  LAR      RB  23  15  15    0    0     0   0  ...  19
# 1      Le'Veon Bell*+  PIT      RB  25  15  15    0    0     0   0  ...  11
# 2        Kareem Hunt*  KAN      RB  22  16  16    0    0     0   0  ...  11
# 3       Alvin Kamara*  NOR      RB  22  16   3    0    0     0   0  ...  14
# 4       Melvin Gordon  LAC      RB  24  16  16    0    0     0   0  ...  12
# 5   DeAndre Hopkins*+  HOU      WR  25  15  15    0    0     0   0  ...  13
# 6     Antonio Brown*+  PIT      WR  29  14  14    0    0     0   0  ...   9
# 7     Russell Wilson*  SEA      QB  29  16  16  339  553  3983  34  ...   3
# 8        Mark Ingram*  NOR      RB  28  16  12    0    0     0   0  ...  12
# 9       LeSean McCoy*  BUF      RB  29  16  16    0    0     0   0  ...   8
# 10   Rob Gronkowski*+  NWE      TE  28  14  14    0    0     0   0  ...   8
# 11      Keenan Allen*  LAC      WR  25  16  15    0    0     0   0  ...   7
# 12      Travis Kelce*  KAN      TE  28  15  15    0    1     0   0  ...   8
# 13  Leonard Fournette  JAX      RB  22  13  13    0    0     0   0  ...  10
# 14       Tyreek Hill*  KAN      WR  23  15  13    0    1     0   0  ...   8
#
#    2PM 2PP FantPt    PPR   DKPt   FDPt  VBD PosRank OvRank
# 0             319  383.3  391.3  351.3  192       1      1
# 1             257  341.6  349.6  299.1  130       2      2
# 2             242  295.2  302.2  268.7  115       3      3
# 3    1        239  320.4  327.4  279.9  112       4      4
# 4             230  288.1  294.1  259.1  103       5      5
# 5             214  309.8  313.8  261.8  103       1      6
# 6    1        209  310.3  313.3  259.8   98       2      7
# 7        2    348  347.9  367.9  358.9   93       1      8
# 8             220  278.0  287.0  249.0   93       6      9
# 9             205  263.6  270.6  234.1   78       7     10
# 10   1        158  227.4  230.4  192.9   77       1     11
# 11            182  284.2  287.2  233.2   71       3     12
# 12            151  233.5  237.5  193.0   69       2     13
# 13            194  230.2  236.2  212.2   67       8     14
# 14            170  245.2  249.2  208.7   59       4     15
#
# [15 rows x 32 columns]
